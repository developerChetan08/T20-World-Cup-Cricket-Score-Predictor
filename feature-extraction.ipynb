# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %%
##Ye col create karna h [batting_team,bowling_team,city,current score,ball left,wickets left,current rr,last five]

# %%
##batting_team,bowling_team this col already exits

# %%
##Check Null Value:-
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
df['venue'].str.split()
# Out:
# 0      [Melbourne, Cricket, Ground]
# 1      [Melbourne, Cricket, Ground]
# 2      [Melbourne, Cricket, Ground]
# 3      [Melbourne, Cricket, Ground]
# 4      [Melbourne, Cricket, Ground]
#                    ...
# 121         [R, Premadasa, Stadium]
# 122         [R, Premadasa, Stadium]
# 123         [R, Premadasa, Stadium]
# 124         [R, Premadasa, Stadium]
# 125         [R, Premadasa, Stadium]
# Name: venue, Length: 63888, dtype: object

# %%
df['venue'].str.split().apply(lambda x:x[0])
# Out:
# 0      Melbourne
# 1      Melbourne
# 2      Melbourne
# 3      Melbourne
# 4      Melbourne
#          ...
# 121            R
# 122            R
# 123            R
# 124            R
# 125            R
# Name: venue, Length: 63888, dtype: object

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])
cities
# Out:
# array(['Melbourne', 'Melbourne', 'Melbourne', ..., 'Colombo', 'Colombo',
#        'Colombo'], dtype=object)

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns = ['venue'],inplace = True)

# %%
##Kaha Matches Hue h 
df['city'].value_counts()
# Out:
# Colombo          4086
# Mirpur           3420
# Johannesburg     3331
# Dubai            2969
# Auckland         2532
#                  ...
# Nairobi           123
# Potchefstroom     122
# Dharamsala        122
# Ahmedabad         121
# Carrara            64
# Name: city, Length: 86, dtype: int64

# %%
##only wo cities lena h jaha minimum 5 matchs hue ho yani minimum 600 ball dali gayi ho

# %%
df['city'].value_counts()[df['city'].value_counts()>600]
# Out:
# Colombo            4086
# Mirpur             3420
# Johannesburg       3331
# Dubai              2969
# Auckland           2532
# Cape Town          2369
# London             2106
# Pallekele          2066
# Barbados           2050
# Sydney             1579
# Melbourne          1574
# Durban             1520
# St Lucia           1487
# Wellington         1350
# Lauderhill         1238
# Hamilton           1219
# Centurion          1189
# Manchester         1144
# Abu Dhabi          1099
# Mumbai              995
# Nottingham          991
# Southampton         987
# Mount Maunganui     938
# Chittagong          868
# Kolkata             844
# Lahore              748
# Delhi               739
# Nagpur              735
# Chandigarh          627
# Adelaide            623
# Bangalore           620
# St Kitts            618
# Cardiff             615
# Christchurch        614
# Trinidad            611
# Name: city, dtype: int64

# %%
df['city'].value_counts()[df['city'].value_counts()>600].shape
# Out:
# (35,)

# %%
df['city'].value_counts()[df['city'].value_counts()>600].index
# Out:
# Index(['Colombo', 'Mirpur', 'Johannesburg', 'Dubai', 'Auckland', 'Cape Town',
#        'London', 'Pallekele', 'Barbados', 'Sydney', 'Melbourne', 'Durban',
#        'St Lucia', 'Wellington', 'Lauderhill', 'Hamilton', 'Centurion',
#        'Manchester', 'Abu Dhabi', 'Mumbai', 'Nottingham', 'Southampton',
#        'Mount Maunganui', 'Chittagong', 'Kolkata', 'Lahore', 'Delhi', 'Nagpur',
#        'Chandigarh', 'Adelaide', 'Bangalore', 'St Kitts', 'Cardiff',
#        'Christchurch', 'Trinidad'],
#       dtype='object')

# %%
df['city'].value_counts()[df['city'].value_counts()>600].index.tolist()
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts()>600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [50501 rows x 7 columns]

# %%
##current_score:- 
df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
#ball col me se over alag karna hai aur ball number alag karna hai
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city over ball_no  balls_bowled  balls_left  wickets_left  \
# 0    Melbourne    0       1             1         119            10
# 1    Melbourne    0       2             2         118            10
# 2    Melbourne    0       3             3         117            10
# 3    Melbourne    0       4             4         116            10
# 4    Melbourne    0       5             5         115            10
# ..         ...  ...     ...           ...         ...           ...
# 121    Colombo   19       3           117           3             2
# 122    Colombo   19       4           118           2             2
# 123    Colombo   19       5           119           1             1
# 124    Colombo   19       6           120           0             1
# 125    Colombo   19       7           121           0             1
#
#      current_score
# 0                0
# 1                0
# 2                1
# 3                3
# 4                3
# ..             ...
# 121            125
# 122            125
# 123            125
# 124            127
# 125            128
#
# [50501 rows x 13 columns]

# %%
##kitni balls faki gayi h ab nikal na hai
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city over ball_no  balls_bowled  balls_left  wickets_left  \
# 0    Melbourne    0       1             1         119            10
# 1    Melbourne    0       2             2         118            10
# 2    Melbourne    0       3             3         117            10
# 3    Melbourne    0       4             4         116            10
# 4    Melbourne    0       5             5         115            10
# ..         ...  ...     ...           ...         ...           ...
# 121    Colombo   19       3           117           3             2
# 122    Colombo   19       4           118           2             2
# 123    Colombo   19       5           119           1             1
# 124    Colombo   19       6           120           0             1
# 125    Colombo   19       7           121           0             1
#
#      current_score
# 0                0
# 1                0
# 2                1
# 3                3
# 4                3
# ..             ...
# 121            125
# 122            125
# 123            125
# 124            127
# 125            128
#
# [50501 rows x 13 columns]

# %%
##balls_left:-
df['balls_left'] = 120 - df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city over ball_no  balls_bowled  balls_left  wickets_left  \
# 0    Melbourne    0       1             1         119            10
# 1    Melbourne    0       2             2         118            10
# 2    Melbourne    0       3             3         117            10
# 3    Melbourne    0       4             4         116            10
# 4    Melbourne    0       5             5         115            10
# ..         ...  ...     ...           ...         ...           ...
# 121    Colombo   19       3           117           3             2
# 122    Colombo   19       4           118           2             2
# 123    Colombo   19       5           119           1             1
# 124    Colombo   19       6           120           0             1
# 125    Colombo   19       7           121          -1             1
#
#      current_score
# 0                0
# 1                0
# 2                1
# 3                3
# 4                3
# ..             ...
# 121            125
# 122            125
# 123            125
# 124            127
# 125            128
#
# [50501 rows x 13 columns]

# %%
##Negative value in balls_left col
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city over ball_no  balls_bowled  balls_left  wickets_left  \
# 0    Melbourne    0       1             1         119            10
# 1    Melbourne    0       2             2         118            10
# 2    Melbourne    0       3             3         117            10
# 3    Melbourne    0       4             4         116            10
# 4    Melbourne    0       5             5         115            10
# ..         ...  ...     ...           ...         ...           ...
# 121    Colombo   19       3           117           3             2
# 122    Colombo   19       4           118           2             2
# 123    Colombo   19       5           119           1             1
# 124    Colombo   19       6           120           0             1
# 125    Colombo   19       7           121           0             1
#
#      current_score
# 0                0
# 1                0
# 2                1
# 3                3
# 4                3
# ..             ...
# 121            125
# 122            125
# 123            125
# 124            127
# 125            128
#
# [50501 rows x 13 columns]

# %%
##wickets_left:-player_dismissed col me wicket player name ki jagah 1 put karna hai
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)

# %%
## player_dismissed col ko integer me change karna hai
df['player_dismissed'] = df['player_dismissed'].astype('int')

# %%
##Apply Cumiletive Sum Function:-
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']

# %%
##Create Wicket_left COl:-
df['current_score'] = df.groupby('match_id').cumsum()['runs']
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city over ball_no  balls_bowled  balls_left  wickets_left
# 0    Melbourne    0       1             1         119            10
# 1    Melbourne    0       2             2         118            10
# 2    Melbourne    0       3             3         117            10
# 3    Melbourne    0       4             4         116            10
# 4    Melbourne    0       5             5         115            10
# ..         ...  ...     ...           ...         ...           ...
# 121    Colombo   19       3           117           3             2
# 122    Colombo   19       4           118           2             2
# 123    Colombo   19       5           119           1             1
# 124    Colombo   19       6           120           0             1
# 125    Colombo   19       7           121           0             1
#
# [50501 rows x 12 columns]

# %%
##Create a CurrentRunRent:-
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 1
# 1           2    Australia    Sri Lanka   0.2     0                 1
# 2           2    Australia    Sri Lanka   0.3     1                 1
# 3           2    Australia    Sri Lanka   0.4     2                 1
# 4           2    Australia    Sri Lanka   0.5     0                 1
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 1
# 122       964    Sri Lanka    Australia  19.4     0                 1
# 123       964    Sri Lanka    Australia  19.5     0                 1
# 124       964    Sri Lanka    Australia  19.6     2                 1
# 125       964    Sri Lanka    Australia  19.7     1                 1
#
#           city over ball_no  balls_bowled  balls_left  wickets_left  \
# 0    Melbourne    0       1             1         119            10
# 1    Melbourne    0       2             2         118            10
# 2    Melbourne    0       3             3         117            10
# 3    Melbourne    0       4             4         116            10
# 4    Melbourne    0       5             5         115            10
# ..         ...  ...     ...           ...         ...           ...
# 121    Colombo   19       3           117           3             2
# 122    Colombo   19       4           118           2             2
# 123    Colombo   19       5           119           1             1
# 124    Colombo   19       6           120           0             1
# 125    Colombo   19       7           121           0             1
#
#      current_score       crr
# 0                0  0.000000
# 1                0  0.000000
# 2                1  2.000000
# 3                3  4.500000
# 4                3  3.600000
# ..             ...       ...
# 121            125  6.410256
# 122            125  6.355932
# 123            125  6.302521
# 124            127  6.350000
# 125            128  6.347107
#
# [50501 rows x 14 columns]

# %%
##Last Five Over Runs:-
groups = df.groupby('match_id')
match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_744\492033648.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 1
# 1           2    Australia    Sri Lanka   0.2     0                 1
# 2           2    Australia    Sri Lanka   0.3     1                 1
# 3           2    Australia    Sri Lanka   0.4     2                 1
# 4           2    Australia    Sri Lanka   0.5     0                 1
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 1
# 122       964    Sri Lanka    Australia  19.4     0                 1
# 123       964    Sri Lanka    Australia  19.5     0                 1
# 124       964    Sri Lanka    Australia  19.6     2                 1
# 125       964    Sri Lanka    Australia  19.7     1                 1
#
#           city over ball_no  balls_bowled  balls_left  wickets_left  \
# 0    Melbourne    0       1             1         119            10
# 1    Melbourne    0       2             2         118            10
# 2    Melbourne    0       3             3         117            10
# 3    Melbourne    0       4             4         116            10
# 4    Melbourne    0       5             5         115            10
# ..         ...  ...     ...           ...         ...           ...
# 121    Colombo   19       3           117           3             2
# 122    Colombo   19       4           118           2             2
# 123    Colombo   19       5           119           1             1
# 124    Colombo   19       6           120           0             1
# 125    Colombo   19       7           121           0             1
#
#      current_score       crr  last_five
# 0                0  0.000000        NaN
# 1                0  0.000000        NaN
# 2                1  2.000000        NaN
# 3                3  4.500000        NaN
# 4                3  3.600000        NaN
# ..             ...       ...        ...
# 121            125  6.410256       32.0
# 122            125  6.355932       32.0
# 123            125  6.302521       32.0
# 124            127  6.350000       33.0
# 125            128  6.347107       32.0
#
# [50501 rows x 15 columns]

# %%
##Create Final Score:-
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')
final_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 50496       964     128    Sri Lanka    Australia  19.3       1
# 50497       964     128    Sri Lanka    Australia  19.4       0
# 50498       964     128    Sri Lanka    Australia  19.5       0
# 50499       964     128    Sri Lanka    Australia  19.6       2
# 50500       964     128    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city over ball_no  balls_bowled  balls_left  \
# 0                     1  Melbourne    0       1             1         119
# 1                     1  Melbourne    0       2             2         118
# 2                     1  Melbourne    0       3             3         117
# 3                     1  Melbourne    0       4             4         116
# 4                     1  Melbourne    0       5             5         115
# ...                 ...        ...  ...     ...           ...         ...
# 50496                 1    Colombo   19       3           117           3
# 50497                 1    Colombo   19       4           118           2
# 50498                 1    Colombo   19       5           119           1
# 50499                 1    Colombo   19       6           120           0
# 50500                 1    Colombo   19       7           121           0
#
#        wickets_left  current_score       crr  last_five
# 0                10              0  0.000000        NaN
# 1                10              0  0.000000        NaN
# 2                10              1  2.000000        NaN
# 3                10              3  4.500000        NaN
# 4                10              3  3.600000        NaN
# ...             ...            ...       ...        ...
# 50496             2            125  6.410256       32.0
# 50497             2            125  6.355932       32.0
# 50498             1            125  6.302521       32.0
# 50499             1            127  6.350000       33.0
# 50500             1            128  6.347107       32.0
#
# [50501 rows x 16 columns]

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
##Remove Missing Value
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
##Bias Problem Create na ho isliye data ko shuffle karna hai
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#       batting_team bowling_team         city  current_score  balls_left  \
# 14154      England    Australia  Southampton            137          21
# 8142   New Zealand        India     Hamilton             95          62
# 70       Australia    Sri Lanka    Melbourne             87          50
# 10758  New Zealand      England   Wellington            150          16
# 26301    Australia      England     Barbados             99          22
# ...            ...          ...          ...            ...         ...
# 40550        India    Australia       Mirpur            125          18
# 39881    Sri Lanka      England   Chittagong             83          52
# 28351     Pakistan  New Zealand     Auckland             90          38
# 48932  Afghanistan  West Indies       Nagpur            103          12
# 22088        India  New Zealand   Wellington            102          27
#
#        wickets_left       crr  last_five  runs_x
# 14154             5  8.303030       35.0     179
# 8142              9  9.827586       49.0     212
# 70                8  7.457143       37.0     168
# 10758             5  8.653846       35.0     176
# 26301             5  6.061224       44.0     147
# ...             ...       ...        ...     ...
# 40550             6  7.352941       51.0     159
# 39881             9  7.323529       39.0     189
# 28351             3  6.585366       22.0     143
# 48932             4  5.722222       39.0     123
# 22088             5  6.580645       32.0     149
#
# [38477 rows x 9 columns]

# %%
#Apply train_test_split
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9879804987252139
# 1.6505752169912422

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '1.7.6'
